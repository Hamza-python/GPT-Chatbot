# %%
from tkinter import *
import tkinter.messagebox
import requests


def send_message():
    user_input = user_input_textbox.get("1.0", END).strip()
    if user_input:
        # Process the user's message and generate a response
        response = query_chatgpt(user_input)

        # Display the user's message and the Chatbot's response
        user_input_textbox.delete("1.0", END)
        chatbot_response_textbox.configure(state=NORMAL)
        chatbot_response_textbox.insert(END, "You: " + user_input + "\n\n")
        chatbot_response_textbox.insert(END, "Chatbot: " + response + "\n\n")
        chatbot_response_textbox.configure(state=DISABLED)

question_response_dict = {
    "مجھے داخلہ کے بارے میں بتائیں":"آپ داخلے کے بارے میں کس قسم کا سوال پوچھنا چاہتے ہیں۔ 1. سپیریئر یونیورسٹی میں داخلے کے کرائٹیریا کیا ہیں؟ 2. سافٹ ویئر انجینئرنگ ڈیپارٹمنٹ کے لیے اہلیت کے تقاضے کیا ہیں؟ 3. مجھے داخلے کے لیے کن دستاویزات کی ضرورت ہے؟ 4. کیا داخلے کے لیے داخلہ امتحان یا انٹرویو ہے؟",
    "سپیریئر یونیورسٹی میں داخلے کے معیار کیا ہیں؟":"یونیورسٹی میں داخلے کے لئے انٹرمیڈیٹ میں کم از کم 50 فیصد نمبرز درکار ہیں۔",
    "سافٹ ویئر انجینئرنگ ڈیپارٹمنٹ کے لیے اہلیت کے تقاضے کیا ہیں؟":"سافٹ ویئر انجینئرنگ ڈیپارٹمنٹ میں داخلے کے لئے انٹرمیڈیٹ میں کم از کم 50 فیصد نمبرز لازمی ہیں۔",
    "مجھے داخلے کے لیے کن دستاویزات کی ضرورت ہے؟":"1۔ نیلے یا سفید بیک گراونڈ کے ساتھ تصاویر، 2۔ سی این آئی سی یا بی فارم کی کاپی 3۔ انٹرمیڈیٹ کے رزلٹ کارڈ کی کاپی 4۔ میٹرک کے رزلٹ کارڈ کی کاپی 5۔ والد کے سی این آئی سی کارڈ کی کاپی",
    "کیا داخلے کے لیے داخلہ امتحان یا انٹرویو ہے؟":"ہاں جی، یونیورسٹی میں داخلے کے لئے داخلہ امتحان ہوتا ہے۔",
    "مجھے یونیورسٹی کے قوانین کے بارے میں بتائیں":" یونیورسٹی کے قوانین کے بارے میں آپ کس قسم کا سوال پوچھنا چاہتے ہیں۔ 1۔ رولز اینڈ ریگولیشنز 2۔ جنرل ڈسپلن رولز اینڈ ریگولیشنز 3۔ فائن رولز اور ریگولیشنز",
    "رولز اینڈ ریگولیشنز":"1۔طلباء کو اساتذہ، انتظامیہ اور ساتھی طلباء کے لئے احترام کا مظاہرہ کرنا ضروری ہے۔ 2۔کیمپس میں یا اس کے قریب کسی بھی سیاسی سرگرمی یا ناشایست رویے کو قابل سزا قرار دیا جائے گا۔ 3۔طلبہ کو کیمپسوں پر اور سپیریئر یونیورسٹی کی تقریبات میں سپیریئر آئی ڈی کارڈ پہننا ضروری ہے۔ 4۔تمام طلبہ کو ڈریس کوڈ کا پابند ہونا ضروری ہے۔",
    "جنرل رولز اینڈ ریگولیشنز":"1۔یونیورسٹی کے علاقے میں سگریٹ پینا مکمل طور پر منع ہے۔ افراد جو اس پر قدم رکھتے ہیں، ان کو خصوصی جرائم، یونیورسٹی سے نکالنے یا دونوں سزاؤں کا سامنا کرنا پڑ سکتا ہے 2۔کلاس میں دیر سے آنے والے طلباء کو غیر حاضر کیا جائے گا۔ 3۔کالج طلباء کی سامان کے بارے میں کسی قسم کے نقصان یا تباہی کے لئے ذمہ دار نہیں ہوتا۔ 4۔طلباء کو ایک بار الاٹ کیے جانے والے سیکشن/رول نمبر کسی بھی صورت میں تبدیل نہیں کیے جائیں گے۔",
    "فائن رولز اور ریگولیشنز":"1۔کالج کے واجبات مقررہ تاریخ تک ادا کیے جائیں بصورت دیگر 100 روپے یومیہ جرمانہ عائد کیا جائے گا۔ 2۔یونیورسٹی کی املاک، کلاس فکسچر یا لیب کے آلات کو نقصان یا نقصان پہنچنے کی صورت میں، اخراجات کی لاگت مذکورہ نقصان طالب علم سے جرمانے کی رقم کے طور پر وصول کیا جائے گا۔ 3۔تمام بقایا جات کی منظوری کے بغیر امتحانی فارم قبول نہیں کیا جائے گا۔",
    "پروگرام کی معلومات":"آپ پروگرام کی معلومات میں کس قسم کا سوال پوچھنا چاہتے ہیں۔ 1۔کیا سپیریئر یونیورسٹی سافٹ ویئر انجینئرنگ کرواتی ہے؟ 2۔سافٹ ویئر انجینئرنگ میں کتنے مضامین ہیں؟ 3۔سافٹ ویئر انجینئرنگ میں کتنے کریڈٹ آورز ہیں؟",
    "کیا سپیریئر یونیورسٹی سافٹ ویئر انجینئرنگ کرواتی ہے؟":"جی ہاں، سپیریئر یونیورسٹی میں سافٹ ویئر انجینئرنگ کروائی جاتی ہے۔",
    "سافٹ ویئر انجینئرنگ میں کتنے مضامین ہیں؟":"سافٹ ویئر انجینئرنگ میں کل چالیس (40) مضامین ہیں۔",
    "سافٹ ویئر انجینئرنگ میں کتنے کریڈٹ آورز ہیں؟":"سافٹ ویئر انجینئرنگ میں کل (132) کریڈٹ آورز ہیں۔",
    "فیصلٹیز اور ریسورسز":"آپ فیصلٹیز اور ریسورسز کے بارے میں کس قسم کا سوال پوچھنا چاہتے ہیں۔ 1۔کیمپس میں کیا سہولیات دستیاب ہیں، جیسے لائبریری، لیبارٹریز، یا کھیلوں کی سہولیات؟ 2۔کیا کوئی تحقیق یا انٹرن شپ کے مواقع دستیاب ہیں؟",
    "کیمپس میں کیا سہولیات دستیاب ہیں، جیسے لائبریری، لیبارٹریز، یا کھیلوں کی سہولیات؟":"کیمپس میں یہ تمام سہولتیں موجود ہیں",
    "کیا کوئی تحقیق یا انٹرن شپ کے مواقع دستیاب ہیں؟":"جی ہاں، تحقیق اور انٹرنشپ کے مواقع دستیاب ہیں۔",
    "فنانشل میٹرز":"آپ فنانشل میٹرز کے بارے میں کس قسم کا سوال پوچھنا چاہتے ہیں۔ 1۔ٹیوشن فیس اور دیگر اخراجات کیا ہیں؟ 2۔کیا کوئی اسکالرشپ، گرانٹس، یا مالی امداد کے مواقع ہیں؟ 3۔کیا میں اپنے اخراجات کو پورا کرنے کے لیے پڑھائی کے دوران پارٹ ٹائم کام کر سکتا ہوں؟",
    "ٹیوشن فیس اور دیگر اخراجات کیا ہیں؟":"سافٹ ویئر انجینئرنگ ڈیپارٹمنٹ کی کل فیس 1200050 روپے ہیں۔",
    "کیا کوئی اسکالرشپ، گرانٹس، یا مالی امداد کے مواقع ہیں؟":"جی ہاں، سکالرشپ اور مالی امداد کے مواقع موجود ہیں۔",
    "کیا میں اپنے اخراجات کو پورا کرنے کے لیے پڑھائی کے دوران پارٹ ٹائم کام کر سکتا ہوں؟":"ہاں آپ اپنی پڑھائی کے ساتھ پارٹ ٹائم جاب آسانی سے کر سکتے ہیں۔"
}

# Update the query_chatgpt function
def query_chatgpt(message):
    
    
    message = "Answer the folwoing questions related to the Superior University Lahore urdu font /n/n" + message
    
    
    url = "https://api.openai.com/v1/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer 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"
    }
    data = {
        "model": "gpt-3.5-turbo",
        "messages": [
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": message}
        ]
    }

    response = requests.post(url, headers=headers, json=data)
    response_data = response.json()

    if "choices" in response_data:
        response = response_data["choices"][0]["message"]["content"]
        # Filter out any mention of OpenAI
        response = response.replace("OpenAI", "Superior University")
        response = response.replace("openai", "Superior University")

        for question, answer in question_response_dict.items():
            if question in message:
                response = answer
                break

        return response
    else:
        return "Oops! Something went wrong."

def get_response(message):
    # Check if the message is in the dataset
    if message in dataset:
        return dataset[message]
    else:
        # Find the most similar question in the dataset
        similar_questions = difflib.get_close_matches(message, dataset.keys(), n=1, cutoff=0.8)
        if similar_questions:
            return dataset[similar_questions[0]]
        else:
            # If no similar question found, use the ChatGPT API
            return query_chatgpt(message)    

# Add more question-response pairs to the question_response_dict dictionary
question_response_dict.update({
    "آپ کا نیٹ ورک کیسے کام کرتا ہے؟": "ہمارا نیٹ ورک بنیادی طور پر ٹکسٹ سے بنیادی طور پر کام کرتا ہے۔",
    "آپ کس زبان میں بات کر سکتے ہیں؟": "میں اردو اور انگلش زبان میں بات کر سکتا ہوں۔",
    "کیا میں اپنے طلبہ کیلئے ویب سائٹ کا لنک حاصل کر سکتا ہوں؟": "جی ہاں، آپ ہمارے ویب سائٹ سے طلبہ کیلئے ویب سائٹ کا لنک حاصل کر سکتے ہیں۔",
    "آپ کی یونیورسٹی کا تعلیمی نظام کیسا ہے؟": "ہماری یونیورسٹی کا تعلیمی نظام عموماً معیاری طور پر مقرر کردہ درجہ بندی اور پڑھائی کی صورت میں ہوتا ہے۔",
    "آپ کی یونیورسٹی کے لئے داخلہ کی آخری تاریخ کیا ہے؟": "داخلہ کی آخری تاریخ ہر سال تبدیل ہوتی ہے، آپ ہمارے داخلہ دفتر سے معلومات حاصل کر سکتے ہیں۔"
})


# Function to close the screen

def iExist():
    iExit = tkinter.messagebox.askyesno("Exit", "Confirm if you want to Exit")
    if iExit > 0:
        root3.destroy()
        return

# Function to reset the message box

def reset():
    user_input_textbox.delete("1.0", END)
    chatbot_response_textbox.configure(state=NORMAL)
    chatbot_response_textbox.delete("1.0", END)
    chatbot_response_textbox.configure(state=DISABLED)

root3 = Tk()
root3.title("Restuarant Management System")
root3.state('zoomed')

frame_tile = Frame(root3, bg = "SLate Gray4")
frame_tile.pack(side=TOP, fill=X)

frame_upper =Frame(root3, bg = "ghost white",bd=10, relief=RIDGE)
frame_upper.pack(side=TOP, fill=BOTH, expand = 1)

frame_left_inUpper = Frame(frame_upper, bg = "SLate Gray4",bd=10, relief=RIDGE)
frame_left_inUpper.pack(side=LEFT, fill=Y, padx= 20, pady=20)

frame_right_inUpper = Frame(frame_upper, bg = "SLate Gray4",bd=10, relief=RIDGE)
frame_right_inUpper.pack(side=LEFT,fill=BOTH, expand = 1, padx= 20, pady=20)

frame_bottom_inRight = Frame(frame_right_inUpper, bg = "SLate Gray4")
frame_bottom_inRight.pack(side=BOTTOM)



lbl_title = Label(frame_tile, font=('arial', 30, 'bold'), text="SUPERIOR CHATBOT", bd=10, relief=RIDGE,
                  bg='ghost white', fg='Slate Gray4', justify=CENTER, width=40)
lbl_title.pack(side=TOP, padx=10, pady=10)


button_Reset = Button(frame_left_inUpper, text="Reset", bd=7, fg="Black", font=('arial', 16, 'bold'), width=20, command=reset)
button_Reset.pack(padx=20, pady=10)

button_Exit = Button(frame_left_inUpper, text="Exit", bd=7, fg="Black", font=('arial', 16, 'bold'), width=20,
                     command=iExist)
button_Exit.pack(padx=20, pady=10)


scrollbar = Scrollbar(frame_right_inUpper,orient=VERTICAL)
scrollbar.pack(side=RIGHT,fill=Y)
chatbot_response_textbox = Text(frame_right_inUpper,yscrollcommand=scrollbar.set)
chatbot_response_textbox.pack(side=TOP,fill=BOTH,expand=1, padx= 10, pady=10)
scrollbar.configure(command = chatbot_response_textbox.yview)

user_input_textbox = Text(frame_right_inUpper, font=("Arial", 14), bg="white", width=70,height=1)
user_input_textbox.pack(side=LEFT,padx=10)

send_button = Button(frame_right_inUpper, text="Send", bg='#4287f5' ,fg="white", font=("Arial", 14, "bold"), command=send_message)
send_button.pack(side=RIGHT, padx=10, pady=10)


root3.mainloop()
